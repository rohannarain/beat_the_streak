# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsapi
import json
import re
import datetime

from tqdm import tqdm
from collections import OrderedDict

# %matplotlib inline

# %%
def generate_teams_dict():
    team_params = {'activeStatus':'Y', 'season':2019, 'sportIds':1, 'fields':'teams,id,name,teamCode,fileCode,teamName,locationName,shortName,venue'}
    teams_info = statsapi.get('teams', team_params)

    teams_dict = {}
    for team in teams_info['teams']:
        teams_dict[team['fileCode']] = team['id']
    return teams_dict

# %%
def get_yesterdays_games():
    yesterday = datetime.datetime.today() - datetime.timedelta(days=1)
    return yesterday.strftime("%m/%d/%Y")

# %%
def get_todays_games():
    return statsapi.schedule(datetime.datetime.today().strftime("%m/%d/%Y"))

def matchups_and_prob_pitchers_dicts(day='today'):
    games_today = get_todays_games()
    if day == 'yesterday':
        games_today = get_yesterdays_games()
        
    home_away_dict = {}
    prob_pitchers_dict = {}
    for game in games_today:
        prob_pitchers_dict[game['away_id']] = game['away_probable_pitcher']
        prob_pitchers_dict[game['home_id']] = game['home_probable_pitcher']
        
        home_away_dict[game['home_id']] = game['away_id']
        
    away_home_dict = {v:k for k, v in home_away_dict.items()}
    return home_away_dict, away_home_dict, prob_pitchers_dict

# %%
def get_player_list(team_id):
    player_names = []
    roster = statsapi.roster(team_id)
    roster_list = roster.split("\n")[:-1]
    for player in roster_list:
        player_names.append(" ".join(player.split()[2:]))
    return player_names

get_player_list(137)
# Out:
# ['Abiatal Avelino',
#  'Alex Dickerson',
#  'Andrew Suarez',
#  'Austin Slater',
#  'Brandon Belt',
#  'Brandon Crawford',
#  'Buster Posey',
#  'Dereck Rodriguez',
#  'Donovan Solano',
#  'Evan Longoria',
#  'Fernando Abad',
#  'Jandel Gustave',
#  'Jeff Samardzija',
#  'Kevin Pillar',
#  'Logan Webb',
#  'Madison Bumgarner',
#  'Mike Yastrzemski',
#  'Reyes Moronta',
#  'Sam Coonrod',
#  'Scooter Gennett',
#  'Stephen Vogt',
#  'Tony Watson',
#  'Trevor Gott',
#  'Tyler Beede',
#  'Will Smith']

# %%
def get_player_id_from_name(player_name):
    try:
        return statsapi.lookup_player(player_name)[0]['id']
    except IndexError:
        return False

def check_pos_player(player_name):
    try:
        return statsapi.lookup_player(player_name)[0]['primaryPosition']['abbreviation'] != "P"
    except IndexError:
        return False

def get_current_season_stats(player_name):

    if not check_pos_player(player_name):
        raise ValueError("Player name entered is not a position player")
        
    player_id = get_player_id_from_name(player_name)
    stats_dict = OrderedDict({"Name": player_name, "ID": player_id, 
                  "Team": statsapi.lookup_player(player_id)[0]['currentTeam']['id']})
    
    # Look up the player's current season hitting stats
    get_player_stats = statsapi.player_stats(player_id, 'hitting') 
    
    # Get the stats for the most recent season
    curr_season_stats = get_player_stats.split("Season Hitting")[-1]
    
    #Break up the stats into a list
    stats_list = curr_season_stats.split("\n")[1:-2]
    for stat in stats_list:
        stat_name = re.search("[A-Za-z]+", stat).group()
        stat_val = re.search("[^:A-Za-z]+", stat).group()
        try:
            stats_dict[stat_name] = float(stat_val)
        except ValueError:
            stats_dict[stat_name] = 0.0
    return stats_dict

# %%
# These functions were defined with the help of toddrob99 on github, who developed the
# MLB-StatsAPI module. I made a post on reddit.com/r/mlbdata, which he mantains to 
# answer questions about making API calls for specific purposes. I asked how to get stats
# over the past x days and how to get head-to-head batting stats. The post is linked
# here: https://www.reddit.com/r/mlbdata/comments/cewwfo/getting_headtohead_batting_stats_and_last_x_games/?

def batting_past_N_days(N, player_id, end_date=datetime.datetime.today()):
    
    start_date = (end_date - datetime.timedelta(days=N)).strftime("%m/%d/%Y")
    end_date = end_date.strftime("%m/%d/%Y")
    hydrate = ('stats(group=[hitting],type=[byDateRange],startDate={},endDate={}),currentTeam'.
               format(start_date, end_date))
    
    params = {'personId': player_id, 'hydrate':hydrate}
    r = statsapi.get('person',params)
    batting_stats = r['people'][0]['stats'][0]['splits'][0]['stat']

    # Only get rate stats for past N days
    filtered = {k + "_p{}d".format(N):(float(v) if v != '.---' or v != '-.--' else 0.0)
                for k, v in batting_stats.items() 
                if type(v) == str 
                and k != 'stolenBasePercentage'
                or k == 'hits'} 
    filtered = OrderedDict(sorted(filtered.items()))
    
    return filtered

def get_h2h_vs_pitcher(batter_id, opponent_id):
    
    hydrate = 'stats(group=[hitting],type=[vsPlayer],opposingPlayerId={},season=2019,sportId=1)'.format(opponent_id)
    params = {'personId': batter_id, 'hydrate':hydrate, 'sportId':1}
    r = statsapi.get('person',params)
    
    try: 
        batting_stats = r['people'][0]['stats'][1]['splits'][0]['stat']
    except KeyError:
        return OrderedDict({'atBats_h2h': 0.0, 'avg_h2h': 0.0, 'hits_h2h': 0.0, 
                            'obp_h2h': 0.0, 'ops_h2h': 0.0, 'slg_h2h': 0.0})
    
    # Only get rate stats vs pitcher
    filtered = {(k + "_h2h"):(float(v) if v != "-.--" and v != ".---" else 0.0)
                for k, v in batting_stats.items() 
                if type(v) == str 
                and k != 'stolenBasePercentage'
                and k != 'atBatsPerHomeRun'
                or k == 'hits'
                or k == 'atBats'} 
    
    filtered = OrderedDict(sorted(filtered.items()))
    
    return filtered

# %%
def pitching_past_N_days(N, player_id, end_date=datetime.datetime.today()):
    
    start_date = (end_date - datetime.timedelta(days=N)).strftime("%m/%d/%Y")
    end_date = end_date.strftime("%m/%d/%Y")
    hydrate = 'stats(group=[pitching],type=[byDateRange],startDate={},endDate={}),currentTeam'.format(start_date, end_date)
    
    params = {'personId': player_id, 'hydrate':hydrate}
    r = statsapi.get('person',params)
    pitching_stats = r['people'][0]['stats'][0]['splits'][0]['stat']
    
    # Only get rate stats for past N days
    filtered = {k + "_p{}d".format(N):float(v) for k, v in pitching_stats.items() 
                if type(v) == str and v != ".---" and v != "-.--"} 
    
    return filtered

# %%
def check_pitcher_right_handed(pitcher_id):
    try:
        params = {'personId': pitcher_id}
        r = statsapi.get('person',params)
        return r['people'][0]['pitchHand']['code'] == 'R'
    except IndexError:
        return False

# %%
def check_batter_right_handed(batter_id):
    try:
        params = {'personId': batter_id}
        r = statsapi.get('person',params)
        return r['people'][0]['batSide']['code'] == 'R'
    except IndexError:
        return False

# %%
def check_pitcher_batter_opposite_hand(batter_id, pitcher_id):
    return check_pitcher_right_handed(pitcher_id) != check_batter_right_handed(batter_id)

# %%
def player_got_hit_in_game(player_id, game_id, home_or_away):
    
    params = {'gamePk':game_id,
      'fields': 'gameData,teams,teamName,shortName,teamStats,batting,atBats,runs,hits,rbi,strikeOuts,baseOnBalls,leftOnBase,players,boxscoreName,liveData,boxscore,teams,players,id,fullName,batting,avg,ops,era,battingOrder,info,title,fieldList,note,label,value'}
    r = statsapi.get('game', params)
    player_stats = r['liveData']['boxscore']['teams'][home_or_away]['players'].get('ID' + str(player_id), False)
    if not player_stats: 
        return False 
    else:
        return player_stats['stats']['batting'].get('hits', 0) > 0

# %%
def convert_to_FL_format(name):
    last_first = name.split(",")
    last_first.reverse()
    last_first[0] = last_first[0].strip()
    return " ".join(last_first)

# %%
def get_opposing_pitcher(player_id, game_id):
    teams = statsapi.get('schedule', {'sportId': '1', 'gamePk': game_id, 
                                      'hydrate':'probablePitcher'})['dates'][0]['games'][0]['teams']
    home_team_id = teams['home']['team']['id']
    away_team_id = teams['away']['team']['id']
    
    home_prob_pitcher = teams['home']['probablePitcher']['fullName']
    away_prob_pitcher = teams['away']['probablePitcher']['fullName']
    
    if statsapi.lookup_player(player_id)[0]['currentTeam']['id'] == home_team_id:
        return away_prob_pitcher
    else: 
        return home_prob_pitcher

# %%
def batting_past_N_games(N, player_id):
    hydrate = 'stats(group=[hitting],type=[lastXGames],limit={}),currentTeam'.format(N)
    
    params = {'personId': player_id, 'hydrate':hydrate}
    
    try:
        r = statsapi.get('person',params)
        batting_stats = r['people'][0]['stats'][0]['splits'][0]['stat']
    except (ValueError, KeyError):
        return {k:v for k, v in (zip(np.arange(5), [0.0]*5))}
    
    # Only get rate stats for past N days
    filtered = {k + "_p{}G".format(N):(float(v) if v != '.---' and v != '-.--' else 0.0)
                for k, v in batting_stats.items() 
                if type(v) == str 
                and k != 'stolenBasePercentage'
                or k == 'hits'} 
    
    filtered = OrderedDict(sorted(filtered.items()))
    
    return filtered

def pitching_past_N_games(N, player_id):
    if player_id == 547989:
        return {k:v for k, v in (zip(np.arange(15), [0.0]*15))}
    
    hydrate = 'stats(group=[pitching],type=[lastXGames],limit={}),currentTeam'.format(N)
    
    params = {'personId': player_id, 'hydrate':hydrate}
    try:
        r = statsapi.get('person',params)
    except ValueError:              # The request fails if a pitcher is making their debut
        return {k:v for k, v in (zip(np.arange(15), [0.0]*15))}
    
    pitching_stats = r['people'][0]['stats'][0]['splits'][0]['stat']
    
    # Only get rate stats for past N days
    filtered = {(k + "_p{}G".format(N)):(float(v) if v != '.---' and v != '-.--' else 0.0)
                for k, v in pitching_stats.items() 
                if type(v) == str} 
    
    filtered = OrderedDict(sorted(filtered.items()))
    
    return filtered

# %%
# This cell generates rows for a DataFrame of batting stats--one row per player

yesterday = (datetime.datetime.today() - datetime.timedelta(days = 1)).strftime("%m/%d/%Y")
today = datetime.datetime.today().strftime("%m/%d/%Y")

###############################################################
# 
# Change GENERATE_TRAIN_DATA to False to generate 
# data for today's games instead, which won't have 
# labels included for whether or not the player
# got a hit
#
GENERATE_TRAIN_DATA = False
#
################################################################

gameday = yesterday
if not GENERATE_TRAIN_DATA:
    gameday = today
    
rows_list = []
for game in tqdm(statsapi.schedule(gameday)):
    
#     if game['status'] not in ['In Progress', 'Final']:
#         continue
    
    game_id = game['game_id']
    away_id = game['away_id']
    home_id = game['home_id']
    home_player_list = get_player_list(home_id)
    away_player_list = get_player_list(away_id)
    
    away_prob_Pname = convert_to_FL_format(game['away_probable_pitcher'])
    home_prob_Pname = convert_to_FL_format(game['home_probable_pitcher'])
    
    away_probable_pitcher = get_player_id_from_name(away_prob_Pname)
    home_probable_pitcher = get_player_id_from_name(home_prob_Pname)
    
    away_pitcher_p5G = pitching_past_N_games(5, away_probable_pitcher)
    home_pitcher_p5G = pitching_past_N_games(5, home_probable_pitcher)
    
    for player in home_player_list:
#         print(player)
        player_id = get_player_id_from_name(player)
        try:
            new_row = list(get_current_season_stats(player).values())
            new_row += list(batting_past_N_games(7, player_id).values())
            new_row += list(batting_past_N_games(15, player_id).values())
            new_row += list(away_pitcher_p5G.values())
            new_row += list(get_h2h_vs_pitcher(player_id, away_probable_pitcher).values())
            new_row.append(float(check_pitcher_batter_opposite_hand(batter_id=player_id, 
                                                                  pitcher_id=away_probable_pitcher)))
            if GENERATE_TRAIN_DATA:
                new_row.append(player_got_hit_in_game(player_id, game_id, 'home'))
                
            rows_list.append(new_row)
        except (ValueError, IndexError):
            continue

    for player in away_player_list:
#         print(player)
        player_id = get_player_id_from_name(player)
        try:
            new_row = list(get_current_season_stats(player).values())
            new_row += list(batting_past_N_games(7, player_id).values())
            new_row += list(batting_past_N_games(15, player_id).values())
            new_row += list(home_pitcher_p5G.values())
            new_row += list(get_h2h_vs_pitcher(player_id, home_probable_pitcher).values())
            new_row.append(float(check_pitcher_batter_opposite_hand(batter_id=player_id, 
                                                                  pitcher_id=away_probable_pitcher)))
            if GENERATE_TRAIN_DATA:
                new_row.append(player_got_hit_in_game(player_id, game_id, 'away'))
                
            rows_list.append(new_row)
        except (ValueError, IndexError):
            continue
# Out:
# 100%|██████████| 15/15 [15:10<00:00, 60.11s/it]

# %%
sample_hitter = get_player_id_from_name("Kevin Pillar")
sample_pitcher = get_player_id_from_name("Jacob DeGrom")
player_stats_columns = list(get_current_season_stats("Kevin Pillar").keys())
player_stats_columns += list(batting_past_N_games(7, sample_hitter).keys())
player_stats_columns += list(batting_past_N_games(15, sample_hitter).keys())
player_stats_columns += list(pitching_past_N_games(5, sample_pitcher).keys())
player_stats_columns += list(get_h2h_vs_pitcher(sample_hitter, sample_pitcher).keys())

if GENERATE_TRAIN_DATA:
    player_stats_columns += ['pitcher_hitter_opposite_hand', 'player_got_hit']
else:
    player_stats_columns += ['pitcher_hitter_opposite_hand']

# %%
player_stats_table = pd.DataFrame(data=rows_list, columns=player_stats_columns)
player_stats_table#[player_stats_table['Name'] == 'Mike Ford'].iloc[0]
# Out:
#                    Name      ID  Team  gamesPlayed  groundOuts  runs  doubles  \
# 0            Adam Engel  641553   145         44.0        19.0  11.0      4.0
# 1          Eloy Jimenez  650391   145         78.0        80.0  40.0      8.0
# 2          James McCann  543510   145         84.0        69.0  45.0     19.0
# 3               Jon Jay  445055   145         31.0        40.0  11.0      8.0
# 4            Jose Abreu  547989   145        112.0       122.0  55.0     24.0
# 5          Leury Garcia  544725   145        105.0       131.0  72.0     21.0
# 6            Matt Skole  605474   145          5.0         1.0   2.0      1.0
# 7          Ryan Cordell  641477   145         74.0        35.0  18.0      6.0
# 8            Ryan Goins  572365   145         21.0        14.0   8.0      5.0
# 9          Tim Anderson  641313   145         79.0        80.0  46.0     17.0
# 10   Welington Castillo  456078   145         48.0        40.0   9.0      6.0
# 11       Yolmer Sanchez  570560   145        104.0        83.0  39.0     12.0
# 12          Chad Pinder  640461   133         86.0        80.0  34.0     15.0
# 13       Chris Herrmann  543302   133         19.0        13.0   7.0      3.0
# 14       Dustin Garneau  572863   133         31.0        18.0  13.0      4.0
# 15     Jurickson Profar  595777   133        101.0       106.0  44.0     16.0
# 16          Khris Davis  501981   133         96.0        79.0  46.0      8.0
# 17        Marcus Semien  543760   133        116.0       126.0  86.0     30.0
# 18           Mark Canha  592192   133         82.0        63.0  49.0     11.0
# 19         Matt Chapman  656305   133        112.0       102.0  71.0     27.0
# 20           Matt Olson  621566   133         82.0        55.0  42.0     15.0
# 21         Nick Martini  605361   133          5.0         2.0   1.0      0.0
# 22      Robbie Grossman  543257   133         98.0        82.0  40.0     17.0
# 23     Stephen Piscotty  572039   133         81.0        79.0  40.0     15.0
# 24    Anthony Santander  623993   110         53.0        50.0  30.0     13.0
# 25         Chance Sisco  642082   110         35.0        21.0  20.0      6.0
# 26          Chris Davis  448801   110         84.0        45.0  21.0      7.0
# 27       Hanser Alberto  593643   110         96.0       109.0  33.0     12.0
# 28        Jace Peterson  607054   110         13.0        11.0   5.0      0.0
# 29      Jonathan Villar  542340   110        114.0       123.0  76.0     24.0
# ..                  ...     ...   ...          ...         ...   ...      ...
# 307        Raimel Tapia  606132   115        103.0        90.0  41.0     21.0
# 308        Ryan McMahon  641857   115         96.0        85.0  49.0     17.0
# 309        Tony Wolters  547172   115         85.0        73.0  33.0     14.0
# 310        Trevor Story  596115   115        102.0        71.0  83.0     28.0
# 311       Yonathan Daza  602074   115          9.0        11.0   1.0      0.0
# 312       Yonder Alonso  475174   115         82.0        66.0  28.0      9.0
# 313       Austin Slater  596103   137         29.0        21.0   9.0      5.0
# 314        Brandon Belt  474832   137        112.0        67.0  58.0     19.0
# 315    Brandon Crawford  543063   137        106.0       107.0  43.0     20.0
# 316        Buster Posey  457763   137         86.0        90.0  33.0     22.0
# 317      Donovan Solano  456781   137         52.0        25.0  18.0      9.0
# 318       Evan Longoria  446334   137         87.0        70.0  38.0     15.0
# 319        Joey Rickard  572073   137         43.0        28.0  10.0      7.0
# 320        Kevin Pillar  607680   137        116.0       121.0  57.0     28.0
# 321    Mike Yastrzemski  573262   137         64.0        46.0  38.0     13.0
# 322      Pablo Sandoval  467055   137        106.0        80.0  42.0     23.0
# 323     Scooter Gennett  571697   137         28.0        24.0   5.0      5.0
# 324        Stephen Vogt  519390   137         66.0        22.0  19.0     18.0
# 325        Andrew Knapp  595284   143         56.0        22.0   9.0      4.0
# 326         Brad Miller  543543   143         43.0        20.0  11.0      3.0
# 327        Bryce Harper  547180   143        114.0        92.0  66.0     30.0
# 328     Cesar Hernandez  514917   143        114.0       137.0  50.0     22.0
# 329     Corey Dickerson  572816   143         49.0        33.0  22.0     18.0
# 330       J.T. Realmuto  592663   143        109.0        89.0  67.0     25.0
# 331           Jay Bruce  457803   143         81.0        51.0  41.0     17.0
# 332         Jean Segura  516416   143        103.0       144.0  62.0     23.0
# 333        Rhys Hoskins  656555   143        114.0        63.0  58.0     24.0
# 334         Roman Quinn  596451   143         38.0        24.0  12.0      2.0
# 335       Scott Kingery  664068   143         82.0        56.0  44.0     23.0
# 336      Sean Rodriguez  446481   143         43.0        17.0  14.0      3.0
#
#      triples  homeRuns  strikeOuts  ...  walksPer9Inn_p5G  whip_p5G  \
# 0        2.0       2.0        38.0  ...              3.24      1.26
# 1        0.0      18.0        89.0  ...              3.24      1.26
# 2        0.0      12.0        97.0  ...              3.24      1.26
# 3        0.0       0.0        22.0  ...              3.24      1.26
# 4        0.0      24.0       109.0  ...              3.24      1.26
# 5        1.0       7.0       106.0  ...              3.24      1.26
# 6        0.0       0.0         6.0  ...              3.24      1.26
# 7        0.0       6.0        60.0  ...              3.24      1.26
# 8        1.0       2.0        21.0  ...              3.24      1.26
# 9        0.0      12.0        68.0  ...              3.24      1.26
# 10       0.0       6.0        48.0  ...              3.24      1.26
# 11       4.0       2.0        83.0  ...              3.24      1.26
# 12       0.0      10.0        56.0  ...              1.29      1.29
# 13       0.0       1.0        20.0  ...              1.29      1.29
# 14       0.0       3.0        19.0  ...              1.29      1.29
# 15       1.0      15.0        58.0  ...              1.29      1.29
# 16       0.0      17.0       102.0  ...              1.29      1.29
# 17       4.0      19.0        74.0  ...              1.29      1.29
# 18       2.0      17.0        64.0  ...              1.29      1.29
# 19       3.0      24.0        99.0  ...              1.29      1.29
# 20       0.0      22.0        83.0  ...              1.29      1.29
# 21       0.0       1.0         1.0  ...              1.29      1.29
# 22       1.0       5.0        59.0  ...              1.29      1.29
# 23       1.0      10.0        76.0  ...              1.29      1.29
# 24       1.0       9.0        38.0  ...              3.48      1.00
# 25       0.0       6.0        45.0  ...              3.48      1.00
# 26       0.0       9.0       111.0  ...              3.48      1.00
# 27       1.0       6.0        35.0  ...              3.48      1.00
# 28       0.0       1.0        10.0  ...              3.48      1.00
# 29       4.0      15.0       120.0  ...              3.48      1.00
# ..       ...       ...         ...  ...               ...       ...
# 307      5.0       8.0        77.0  ...              2.05      0.95
# 308      1.0      12.0       100.0  ...              2.05      0.95
# 309      2.0       1.0        47.0  ...              2.05      0.95
# 310      5.0      26.0       118.0  ...              2.05      0.95
# 311      0.0       0.0         5.0  ...              2.05      0.95
# 312      0.0       8.0        60.0  ...              2.05      0.95
# 313      2.0       3.0        28.0  ...              2.59      1.15
# 314      2.0      12.0        94.0  ...              2.59      1.15
# 315      1.0       9.0        94.0  ...              2.59      1.15
# 316      0.0       6.0        51.0  ...              2.59      1.15
# 317      0.0       4.0        31.0  ...              2.59      1.15
# 318      2.0      13.0        69.0  ...              2.59      1.15
# 319      2.0       2.0        33.0  ...              2.59      1.15
# 320      1.0      13.0        67.0  ...              2.59      1.15
# 321      2.0      11.0        61.0  ...              2.59      1.15
# 322      0.0      14.0        67.0  ...              2.59      1.15
# 323      0.0       1.0        24.0  ...              2.59      1.15
# 324      2.0       5.0        43.0  ...              2.59      1.15
# 325      0.0       1.0        32.0  ...              1.86      1.52
# 326      1.0       4.0        24.0  ...              1.86      1.52
# 327      0.0      20.0       132.0  ...              1.86      1.52
# 328      3.0       8.0        64.0  ...              1.86      1.52
# 329      0.0       6.0        28.0  ...              1.86      1.52
# 330      1.0      15.0        99.0  ...              1.86      1.52
# 331      0.0      24.0        75.0  ...              1.86      1.52
# 332      3.0      11.0        51.0  ...              1.86      1.52
# 333      4.0      24.0       115.0  ...              1.86      1.52
# 334      0.0       3.0        30.0  ...              1.86      1.52
# 335      2.0      14.0        94.0  ...              1.86      1.52
# 336      0.0       3.0        26.0  ...              1.86      1.52
#
#      winPercentage_p5G  atBats_h2h  avg_h2h  hits_h2h  obp_h2h  ops_h2h  \
# 0                 1.00         5.0    0.400       2.0    0.400    0.800
# 1                 1.00         3.0    0.333       1.0    0.333    0.666
# 2                 1.00         8.0    0.250       2.0    0.400    0.650
# 3                 1.00        23.0    0.261       6.0    0.261    0.522
# 4                 1.00        18.0    0.167       3.0    0.211    0.489
# 5                 1.00         6.0    0.167       1.0    0.167    0.334
# 6                 1.00         0.0    0.000       0.0    0.000    0.000
# 7                 1.00         3.0    0.333       1.0    0.333    0.666
# 8                 1.00         3.0    0.000       0.0    0.000    0.000
# 9                 1.00        10.0    0.400       4.0    0.455    1.155
# 10                1.00         7.0    0.143       1.0    0.250    0.536
# 11                1.00        11.0    0.000       0.0    0.000    0.000
# 12                0.00         0.0    0.000       0.0    0.000    0.000
# 13                0.00         1.0    0.000       0.0    0.000    0.000
# 14                0.00         0.0    0.000       0.0    0.000    0.000
# 15                0.00         4.0    0.000       0.0    0.000    0.000
# 16                0.00         3.0    0.333       1.0    0.333    0.666
# 17                0.00         4.0    0.750       3.0    0.800    1.550
# 18                0.00         4.0    0.750       3.0    0.800    1.800
# 19                0.00         2.0    1.000       2.0    1.000    2.500
# 20                0.00         2.0    0.500       1.0    0.500    1.000
# 21                0.00         0.0    0.000       0.0    0.000    0.000
# 22                0.00         4.0    0.250       1.0    0.400    0.650
# 23                0.00         3.0    0.000       0.0    0.000    0.000
# 24                1.00         2.0    0.000       0.0    0.000    0.000
# 25                1.00         0.0    0.000       0.0    0.000    0.000
# 26                1.00         9.0    0.333       3.0    0.400    0.956
# 27                1.00         7.0    0.429       3.0    0.429    0.858
# 28                1.00         4.0    0.000       0.0    0.200    0.200
# 29                1.00         7.0    0.143       1.0    0.143    0.286
# ..                 ...         ...      ...       ...      ...      ...
# 307               0.67         3.0    0.000       0.0    0.000    0.000
# 308               0.67         2.0    0.000       0.0    0.000    0.000
# 309               0.67         2.0    0.500       1.0    0.500    1.000
# 310               0.67         3.0    1.000       3.0    1.000    2.333
# 311               0.67         0.0    0.000       0.0    0.000    0.000
# 312               0.67         0.0    0.000       0.0    0.000    0.000
# 313               0.50         2.0    0.000       0.0    0.333    0.333
# 314               0.50         0.0    0.000       0.0    0.000    0.000
# 315               0.50         2.0    0.000       0.0    0.000    0.000
# 316               0.50         3.0    0.000       0.0    0.000    0.000
# 317               0.50         5.0    0.200       1.0    0.200    0.400
# 318               0.50         3.0    1.000       3.0    1.000    3.667
# 319               0.50         3.0    0.333       1.0    0.333    0.666
# 320               0.50        15.0    0.067       1.0    0.067    0.134
# 321               0.50         3.0    0.333       1.0    0.333    0.666
# 322               0.50         3.0    0.000       0.0    0.000    0.000
# 323               0.50         0.0    0.000       0.0    0.000    0.000
# 324               0.50         0.0    0.000       0.0    0.000    0.000
# 325               0.25         0.0    0.000       0.0    0.000    0.000
# 326               0.25         0.0    0.000       0.0    0.000    0.000
# 327               0.25         1.0    0.000       0.0    0.667    0.667
# 328               0.25         3.0    0.667       2.0    0.667    1.334
# 329               0.25         0.0    0.000       0.0    0.000    0.000
# 330               0.25         3.0    0.667       2.0    0.667    1.334
# 331               0.25         0.0    0.000       0.0    0.000    0.000
# 332               0.25         3.0    0.667       2.0    0.667    1.667
# 333               0.25         3.0    0.333       1.0    0.333    1.666
# 334               0.25         0.0    0.000       0.0    0.000    0.000
# 335               0.25         3.0    0.000       0.0    0.000    0.000
# 336               0.25         0.0    0.000       0.0    0.000    0.000
#
#      slg_h2h  pitcher_hitter_opposite_hand
# 0      0.400                           0.0
# 1      0.333                           0.0
# 2      0.250                           0.0
# 3      0.261                           1.0
# 4      0.278                           0.0
# 5      0.167                           1.0
# 6      0.000                           1.0
# 7      0.333                           0.0
# 8      0.000                           1.0
# 9      0.700                           0.0
# 10     0.286                           0.0
# 11     0.000                           1.0
# 12     0.000                           0.0
# 13     0.000                           1.0
# 14     0.000                           0.0
# 15     0.000                           1.0
# 16     0.333                           0.0
# 17     0.750                           0.0
# 18     1.000                           0.0
# 19     1.500                           0.0
# 20     0.500                           1.0
# 21     0.000                           1.0
# 22     0.250                           1.0
# 23     0.000                           0.0
# 24     0.000                           0.0
# 25     0.000                           0.0
# 26     0.556                           0.0
# 27     0.429                           1.0
# 28     0.000                           0.0
# 29     0.143                           0.0
# ..       ...                           ...
# 307    0.000                           0.0
# 308    0.000                           0.0
# 309    0.500                           0.0
# 310    1.333                           1.0
# 311    0.000                           1.0
# 312    0.000                           0.0
# 313    0.000                           1.0
# 314    0.000                           0.0
# 315    0.000                           0.0
# 316    0.000                           1.0
# 317    0.200                           1.0
# 318    2.667                           1.0
# 319    0.333                           1.0
# 320    0.067                           1.0
# 321    0.333                           0.0
# 322    0.000                           0.0
# 323    0.000                           0.0
# 324    0.000                           0.0
# 325    0.000                           0.0
# 326    0.000                           0.0
# 327    0.000                           0.0
# 328    0.667                           0.0
# 329    0.000                           0.0
# 330    0.667                           1.0
# 331    0.000                           0.0
# 332    1.000                           1.0
# 333    1.333                           1.0
# 334    0.000                           0.0
# 335    0.000                           1.0
# 336    0.000                           1.0
#
# [337 rows x 67 columns]

# %%
player_stats_table.to_csv("data/player_stats/player_stats_{}.csv".format(gameday.replace("/", "_")), index=False)

# %%
len(batting_past_N_games(15, get_player_id_from_name("Buster Posey"))) == len(batting_past_N_games(15, get_player_id_from_name("Adam Engel")))
# Out:
# True

# %%
(len(get_h2h_vs_pitcher(get_player_id_from_name("Buster Posey"), get_player_id_from_name("Erick Fedde")))
    == len(get_h2h_vs_pitcher(get_player_id_from_name("Adam Engel"), get_player_id_from_name("Daniel Norris"))))
# Out:
# False

# %%
get_h2h_vs_pitcher(get_player_id_from_name("Buster Posey"), get_player_id_from_name("Erick Fedde"))
# Out:
# OrderedDict([('atBats_h2h', 0.0),
#              ('avg_h2h', 0.0),
#              ('hits_h2h', 0.0),
#              ('obp_h2h', 0.0),
#              ('ops_h2h', 0.0),
#              ('slg_h2h', 0.0)])

# %%
get_h2h_vs_pitcher(get_player_id_from_name("Adam Engel"), get_player_id_from_name("Daniel Norris"))
# Out:
# OrderedDict([('atBatsPerHomeRun_h2h', 0.0),
#              ('atBats_h2h', 4.0),
#              ('avg_h2h', 0.0),
#              ('hits_h2h', 0.0),
#              ('obp_h2h', 0.0),
#              ('ops_h2h', 0.0),
#              ('slg_h2h', 0.0)])

# %%
get_current_season_stats(get_player_id_from_name("Yasiel Puig"))
# Out:
# OrderedDict([('Name', 624577),
#              ('ID', 624577),
#              ('Team', 114),
#              ('gamesPlayed', 104.0),
#              ('groundOuts', 80.0),
#              ('runs', 52.0),
#              ('doubles', 17.0),
#              ('triples', 1.0),
#              ('homeRuns', 22.0),
#              ('strikeOuts', 90.0),
#              ('baseOnBalls', 25.0),
#              ('intentionalWalks', 1.0),
#              ('hits', 98.0),
#              ('hitByPitch', 5.0),
#              ('avg', 0.253),
#              ('atBats', 387.0),
#              ('obp', 0.305),
#              ('slg', 0.473),
#              ('ops', 0.778),
#              ('caughtStealing', 5.0),
#              ('stolenBases', 16.0),
#              ('stolenBasePercentage', 0.762),
#              ('groundIntoDoublePlay', 9.0),
#              ('numberOfPitches', 1503.0),
#              ('plateAppearances', 420.0),
#              ('totalBases', 183.0),
#              ('rbi', 63.0),
#              ('leftOnBase', 173.0),
#              ('sacBunts', 0.0),
#              ('sacFlies', 3.0),
#              ('babip', 0.273),
#              ('groundOutsToAirouts', 0.66),
#              ('atBatsPerHomeRun', 17.59)])

# %%
get_current_season_stats(get_player_id_from_name("Buster Posey"))
# Out:
# OrderedDict([('Name', 457763),
#              ('ID', 457763),
#              ('Team', 137),
#              ('gamesPlayed', 81.0),
#              ('groundOuts', 84.0),
#              ('runs', 33.0),
#              ('doubles', 21.0),
#              ('triples', 0.0),
#              ('homeRuns', 6.0),
#              ('strikeOuts', 50.0),
#              ('baseOnBalls', 24.0),
#              ('intentionalWalks', 0.0),
#              ('hits', 73.0),
#              ('hitByPitch', 4.0),
#              ('avg', 0.262),
#              ('atBats', 279.0),
#              ('obp', 0.328),
#              ('slg', 0.401),
#              ('ops', 0.729),
#              ('caughtStealing', 0.0),
#              ('stolenBases', 0.0),
#              ('stolenBasePercentage', 0.0),
#              ('groundIntoDoublePlay', 10.0),
#              ('numberOfPitches', 1194.0),
#              ('plateAppearances', 308.0),
#              ('totalBases', 112.0),
#              ('rbi', 33.0),
#              ('leftOnBase', 111.0),
#              ('sacBunts', 0.0),
#              ('sacFlies', 1.0),
#              ('babip', 0.299),
#              ('groundOutsToAirouts', 1.15),
#              ('atBatsPerHomeRun', 46.5)])

# %%
len(pitching_past_N_games(5, get_player_id_from_name("Jacob DeGrom")))
# Out:
# 15

# %%
statsapi.schedule()
# Out:
# [{'away_id': 145,
#   'away_name': 'Chicago White Sox',
#   'away_pitcher_note': 'Lopez didn’t have his best stuff in his start Tuesday against the Mets, but he still managed to hold them to two runs over 5 1/3 innings. Lopez has a 2.05 ERA and a .194 batting average against since the All-Star break.',
#   'away_probable_pitcher': 'Lopez, Reynaldo',
#   'away_score': 10,
#   'current_inning': 9,
#   'doubleheader': 'N',
#   'game_date': '2019-08-04',
#   'game_datetime': '2019-08-04T17:05:00Z',
#   'game_id': 567118,
#   'game_num': 1,
#   'game_type': 'R',
#   'home_id': 143,
#   'home_name': 'Philadelphia Phillies',
#   'home_pitcher_note': 'Smyly has been a godsend through two starts with the Phillies. He has allowed just one earned run in 13 innings, after struggling earlier this season with the Rangers. He is throwing his cutter more, which has been a factor to his success.',
#   'home_probable_pitcher': 'Smyly, Drew',
#   'home_score': 3,
#   'inning_state': 'Bottom',
#   'status': 'In Progress',
#   'summary': '2019-08-04 - Chicago White Sox (10) @ Philadelphia Phillies (3) (Bottom of the 9th)'},
#  {'away_id': 141,
#   'away_name': 'Toronto Blue Jays',
#   'away_pitcher_note': 'Reid-Foley will get another start after impressing in his first outing since being recalled from Triple-A Buffalo. The right-hander tossed five scoreless innings his last time out and he owns a 2.55 ERA across 17 2/3 innings (three starts) this season.',
#   'away_probable_pitcher': 'Reid-Foley, Sean',
#   'away_score': 5,
#   'current_inning': 9,
#   'doubleheader': 'N',
#   'game_date': '2019-08-04',
#   'game_datetime': '2019-08-04T17:05:00Z',
#   'game_id': 564984,
#   'game_num': 1,
#   'game_type': 'R',
#   'home_id': 110,
#   'home_name': 'Baltimore Orioles',
#   'home_pitcher_note': "The Orioles liked the way it looked when Yacabonis opened for Tom Eshelman last week in Anaheim, so they're trying it again. Yacabonis will make his fourth start as an opener, followed by the rookie Eshelman for the bulk of the innings. Eshelman, a rookie, is 0-2 with a 6.35 ERA in five games this season.",
#   'home_probable_pitcher': 'Yacabonis, Jimmy',
#   'home_score': 6,
#   'inning_state': 'Top',
#   'status': 'In Progress',
#   'summary': '2019-08-04 - Toronto Blue Jays (5) @ Baltimore Orioles (6) (Top of the 9th)'},
#  {'away_id': 146,
#   'away_name': 'Miami Marlins',
#   'away_pitcher_note': 'Since he sat out most of June with left hip inflammation, Smith has thrown three quality starts in five outings, posting a 3.48 July ERA. On Monday, the lefty allowed four runs on four hits while striking out nine and walking one over seven innings vs. Arizona.',
#   'away_probable_pitcher': 'Smith, Caleb',
#   'away_score': 2,
#   'current_inning': 9,
#   'doubleheader': 'N',
#   'game_date': '2019-08-04',
#   'game_datetime': '2019-08-04T17:10:00Z',
#   'game_id': 566719,
#   'game_num': 1,
#   'game_type': 'R',
#   'home_id': 139,
#   'home_name': 'Tampa Bay Rays',
#   'home_pitcher_note': 'Chirinos will be making his 23rd appearance of the season and his 17th start. In 16 previous starts, Chirinos has a 3.64 ERA over 96 1/3 innings of work.',
#   'home_probable_pitcher': 'Chirinos, Yonny',
#   'home_score': 7,
#   'inning_state': 'Top',
#   'losing_pitcher': 'Caleb Smith',
#   'losing_team': 'Miami Marlins',
#   'save_pitcher': None,
#   'status': 'Final',
#   'summary': '2019-08-04 - Miami Marlins (2) @ Tampa Bay Rays (7) (Final)',
#   'winning_pitcher': 'Yonny Chirinos',
#   'winning_team': 'Tampa Bay Rays'},
#  {'away_id': 108,
#   'away_name': 'Los Angeles Angels',
#   'away_pitcher_note': 'Barria went five innings in a loss against the Tigers last time out, surrendering three runs (two earned) on four hits. He was hurt by two homers.',
#   'away_probable_pitcher': 'Barria, Jaime',
#   'away_score': 2,
#   'current_inning': 9,
#   'doubleheader': 'N',
#   'game_date': '2019-08-04',
#   'game_datetime': '2019-08-04T17:10:00Z',
#   'game_id': 565374,
#   'game_num': 1,
#   'game_type': 'R',
#   'home_id': 114,
#   'home_name': 'Cleveland Indians',
#   'home_pitcher_note': 'Bieber has made one career start against the Angels, giving up two runs in 5 2/3 frames with seven strikeouts last season. In his last outing, Bieber allowed two runs on nine hits with eight strikeouts in seven innings against the Astros.',
#   'home_probable_pitcher': 'Bieber, Shane',
#   'home_score': 6,
#   'inning_state': 'Top',
#   'losing_pitcher': 'Jaime Barria',
#   'losing_team': 'Los Angeles Angels',
#   'save_pitcher': None,
#   'status': 'Game Over',
#   'summary': '2019-08-04 - Los Angeles Angels (2) @ Cleveland Indians (6) (Game Over)',
#   'winning_pitcher': 'Shane Bieber',
#   'winning_team': 'Cleveland Indians'},
#  {'away_id': 113,
#   'away_name': 'Cincinnati Reds',
#   'away_pitcher_note': "Gray acknowledged not having his best stuff during Monday's 11-6 win over the Pirates. His streak of five straight quality starts ended, but he's still 3-1 with a 2.42 ERA over his last six games.",
#   'away_probable_pitcher': 'Gray, Sonny',
#   'away_score': 3,
#   'current_inning': 8,
#   'doubleheader': 'N',
#   'game_date': '2019-08-04',
#   'game_datetime': '2019-08-04T17:20:00Z',
#   'game_id': 567223,
#   'game_num': 1,
#   'game_type': 'R',
#   'home_id': 144,
#   'home_name': 'Atlanta Braves',
#   'home_pitcher_note': 'Teheran credits improved fastball command for the 1.48 ERA he posted in five July starts.  The veteran hurler has allowed two earned runs or fewer in 14 of his past 16 starts.',
#   'home_probable_pitcher': 'Teheran, Julio',
#   'home_score': 0,
#   'inning_state': 'Bottom',
#   'status': 'In Progress',
#   'summary': '2019-08-04 - Cincinnati Reds (3) @ Atlanta Braves (0) (Bottom of the 8th)'},
#  {'away_id': 121,
#   'away_name': 'New York Mets',
#   'away_pitcher_note': 'Untraded at the Deadline, Syndergaard will look to keep his strong second half rolling. In four starts since the All-Star break, Syndergaard owns a 1.91 ERA with 36 strikeouts and seven walks in 28 1/3 innings.',
#   'away_probable_pitcher': 'Syndergaard, Noah',
#   'away_score': 13,
#   'current_inning': 8,
#   'doubleheader': 'N',
#   'game_date': '2019-08-04',
#   'game_datetime': '2019-08-04T17:35:00Z',
#   'game_id': 566232,
#   'game_num': 1,
#   'game_type': 'R',
#   'home_id': 134,
#   'home_name': 'Pittsburgh Pirates',
#   'home_pitcher_note': "After a shaky outing against the Cardinals at home, Musgrove bounced back with a quality outing to beat the Reds in Cincinnati on Tuesday. The righty held Cincy to two runs on five hits over six innings to snap Pittsburgh's nine-game losing streak.",
#   'home_probable_pitcher': 'Musgrove, Joe',
#   'home_score': 1,
#   'inning_state': 'Bottom',
#   'status': 'In Progress',
#   'summary': '2019-08-04 - New York Mets (13) @ Pittsburgh Pirates (1) (Bottom of the 8th)'},
#  {'away_id': 136,
#   'away_name': 'Seattle Mariners',
#   'away_pitcher_note': 'After 105 relief appearances, the 26-year-old will make the first start of his career as the opener before turning things over to veteran lefty Tommy Milone. Tuivailala has pitched 4 1/3 innings in four games since coming back from Achilles’ surgery.',
#   'away_probable_pitcher': 'Tuivailala, Sam',
#   'away_score': 0,
#   'current_inning': 6,
#   'doubleheader': 'N',
#   'game_date': '2019-08-04',
#   'game_datetime': '2019-08-04T18:10:00Z',
#   'game_id': 565661,
#   'game_num': 1,
#   'game_type': 'R',
#   'home_id': 117,
#   'home_name': 'Houston Astros',
#   'home_pitcher_note': "Verlander has recorded at least 11 strikeouts in each of his last three starts, giving him 31 double-digit strikeout games in his career (six this season). He's 4-0 with a 1.44 ERA in his last four starts and leads the Majors with a 0.81 WHIP on the year.",
#   'home_probable_pitcher': 'Verlander, Justin',
#   'home_score': 1,
#   'inning_state': 'Bottom',
#   'status': 'In Progress',
#   'summary': '2019-08-04 - Seattle Mariners (0) @ Houston Astros (1) (Bottom of the 6th)'},
#  {'away_id': 118,
#   'away_name': 'Kansas City Royals',
#   'away_pitcher_note': 'Keller pitched better than his line in a loss to Toronto last time out. He gave up four runs on eight hits over seven innings. All four runs came via home runs -- two solo blasts and a two-run shot -- and each came on a hanging slider.',
#   'away_probable_pitcher': 'Keller, Brad',
#   'away_score': 0,
#   'current_inning': 6,
#   'doubleheader': 'N',
#   'game_date': '2019-08-04',
#   'game_datetime': '2019-08-04T18:10:00Z',
#   'game_id': 567016,
#   'game_num': 1,
#   'game_type': 'R',
#   'home_id': 142,
#   'home_name': 'Minnesota Twins',
#   'home_pitcher_note': 'Jake Odorizzi was a late scratch in the finale against the Royals. The Twins called up righty Devin Smeltzer from Triple-A to make his third start of the season.',
#   'home_probable_pitcher': 'Smeltzer, Devin',
#   'home_score': 1,
#   'inning_state': 'End',
#   'status': 'In Progress',
#   'summary': '2019-08-04 - Kansas City Royals (0) @ Minnesota Twins (1) (End of the 6th)'},
#  {'away_id': 158,
#   'away_name': 'Milwaukee Brewers',
#   'away_pitcher_note': 'Houser rejoined the rotation on Tuesday at Oakland and delivered five solid innings on 69 pitches. He should be able to pitch deeper into the game against the Cubs if circumstances allow it.',
#   'away_probable_pitcher': 'Houser, Adrian',
#   'away_score': 1,
#   'current_inning': 5,
#   'doubleheader': 'N',
#   'game_date': '2019-08-04',
#   'game_datetime': '2019-08-04T18:20:00Z',
#   'game_id': 565180,
#   'game_num': 1,
#   'game_type': 'R',
#   'home_id': 112,
#   'home_name': 'Chicago Cubs',
#   'home_pitcher_note': 'Darvish had a hard-luck loss on Tuesday in St. Louis, where he allowed two runs in six innings and ended with nine strikeouts vs. no walks. The righty has a 2.25 ERA with 30 strikeouts and two walks in 24 innings (four starts) in the second half.',
#   'home_probable_pitcher': 'Darvish, Yu',
#   'home_score': 4,
#   'inning_state': 'Bottom',
#   'status': 'In Progress',
#   'summary': '2019-08-04 - Milwaukee Brewers (1) @ Chicago Cubs (4) (Bottom of the 5th)'},
#  {'away_id': 116,
#   'away_name': 'Detroit Tigers',
#   'away_pitcher_note': 'In his most recent start, Zimmermann picked up his first win of the season in 14 tries, holding the Angels to two runs in 5 1/3 innings while striking out two.',
#   'away_probable_pitcher': 'Zimmermann, Jordan',
#   'away_score': 0,
#   'current_inning': 3,
#   'doubleheader': 'N',
#   'game_date': '2019-08-04',
#   'game_datetime': '2019-08-04T19:05:00Z',
#   'game_id': 566825,
#   'game_num': 1,
#   'game_type': 'R',
#   'home_id': 140,
#   'home_name': 'Texas Rangers',
#   'home_pitcher_note': 'Payano is making his second Major League start and fourth appearance. He allowed three runs in 5 1/3 innings in his last start against Oakland. He pitched six innings over two relief outings, allowing just one run on three hits with seven strikeouts.',
#   'home_probable_pitcher': 'Payano, Pedro',
#   'home_score': 2,
#   'inning_state': 'End',
#   'status': 'In Progress',
#   'summary': '2019-08-04 - Detroit Tigers (0) @ Texas Rangers (2) (End of the 3rd)'},
#  {'away_id': 137,
#   'away_name': 'San Francisco Giants',
#   'away_pitcher_note': "Beede logged a 1.66 ERA over his first three starts of July, but he didn't finish the month on the best note, allowing eight runs on 20 hits over 10 2/3 innings in his final two outings. He gave up two runs over two innings vs. Colorado on May 9.",
#   'away_probable_pitcher': 'Beede, Tyler',
#   'away_score': 2,
#   'current_inning': 3,
#   'doubleheader': 'N',
#   'game_date': '2019-08-04',
#   'game_datetime': '2019-08-04T19:10:00Z',
#   'game_id': 565469,
#   'game_num': 1,
#   'game_type': 'R',
#   'home_id': 115,
#   'home_name': 'Colorado Rockies',
#   'home_pitcher_note': 'After a stellar start on the road at Washington (one unearned run in six innings), Freeland faced the Dodgers at home and gave up three home runs and eight runs (seven earned) in 3 2/3 innings.',
#   'home_probable_pitcher': 'Freeland, Kyle',
#   'home_score': 5,
#   'inning_state': 'Bottom',
#   'status': 'In Progress',
#   'summary': '2019-08-04 - San Francisco Giants (2) @ Colorado Rockies (5) (Bottom of the 3rd)'},
#  {'away_id': 138,
#   'away_name': 'St. Louis Cardinals',
#   'away_pitcher_note': "Wainwright allowed one run in 5 2/3 innings Tuesday in the Cardinals' win over the Cubs. He walked three -- two in the top of the sixth to load the bases -- and struck out five. He hasn't made it out of the sixth in any of his last three starts.",
#   'away_probable_pitcher': 'Wainwright, Adam',
#   'away_score': 0,
#   'current_inning': 1,
#   'doubleheader': 'N',
#   'game_date': '2019-08-04',
#   'game_datetime': '2019-08-04T20:07:00Z',
#   'game_id': 566143,
#   'game_num': 1,
#   'game_type': 'R',
#   'home_id': 133,
#   'home_name': 'Oakland Athletics',
#   'home_pitcher_note': "Roark, who will be making his A's debut, must be glad that July is over. In five starts during the month, he compiled a 7.30 ERA. He didn’t last beyond five innings in any of his final four starts with Cincinnati.",
#   'home_probable_pitcher': 'Roark, Tanner',
#   'home_score': 0,
#   'inning_state': 'Top',
#   'status': 'In Progress',
#   'summary': '2019-08-04 - St. Louis Cardinals (0) @ Oakland Athletics (0) (Top of the 1st)'},
#  {'away_id': 120,
#   'away_name': 'Washington Nationals',
#   'away_pitcher_note': 'Corbin spent six seasons in Arizona, where he made his MLB debut in 2012. He went 56-54 with a 3.91 ERA with the D-backs before signing a six-year deal with the Nats as a free agent this past winter. This will be his first matchup with his former team.',
#   'away_probable_pitcher': 'Corbin, Patrick',
#   'away_score': 0,
#   'current_inning': 1,
#   'doubleheader': 'N',
#   'game_date': '2019-08-04',
#   'game_datetime': '2019-08-04T20:10:00Z',
#   'game_id': 564884,
#   'game_num': 1,
#   'game_type': 'R',
#   'home_id': 109,
#   'home_name': 'Arizona Diamondbacks',
#   'home_pitcher_note': 'Clarke has won his last two starts. Last time out he held the Yankees to one unearned run on three hits over 5 1/3 innings. In his start on July 24, he allowed two runs over six innings to the Orioles.',
#   'home_probable_pitcher': 'Clarke, Taylor',
#   'home_score': 0,
#   'inning_state': 'Top',
#   'status': 'In Progress',
#   'summary': '2019-08-04 - Washington Nationals (0) @ Arizona Diamondbacks (0) (Top of the 1st)'},
#  {'away_id': 135,
#   'away_name': 'San Diego Padres',
#   'away_pitcher_note': "Paddack's first two starts in Los Angeles were polar opposites. He coughed up six runs -- although only three were earned -- in mid-May at Dodger Stadium before pitching 5 2/3 shutout innings there in July. Paddack owns a 2.08 ERA since he was sent to the Minors for rest in mid-June.",
#   'away_probable_pitcher': 'Paddack, Chris',
#   'away_score': 0,
#   'current_inning': 1,
#   'doubleheader': 'N',
#   'game_date': '2019-08-04',
#   'game_datetime': '2019-08-04T20:10:00Z',
#   'game_id': 565856,
#   'game_num': 1,
#   'game_type': 'R',
#   'home_id': 119,
#   'home_name': 'Los Angeles Dodgers',
#   'home_pitcher_note': 'The wheels came off in the fifth inning at Coors Field for Maeda, but his task was made more difficult by repeated defensive breakdowns behind him. Look for Julio Urias to follow him to the mound.',
#   'home_probable_pitcher': 'Maeda, Kenta',
#   'home_score': 0,
#   'inning_state': 'Top',
#   'status': 'In Progress',
#   'summary': '2019-08-04 - San Diego Padres (0) @ Los Angeles Dodgers (0) (Top of the 1st)'},
#  {'away_id': 111,
#   'away_name': 'Boston Red Sox',
#   'away_pitcher_note': 'Price has struggled since the All-Star break, going 0-2 with a 6.52 ERA in four starts. The lefty won at Yankee Stadium on June 2, holding the Yankees to two runs over 6 1/3 innings. He is 4-3 with a 4.13 ERA in 12 road starts this season.',
#   'away_probable_pitcher': 'Price, David',
#   'away_score': 0,
#   'current_inning': 1,
#   'doubleheader': 'N',
#   'game_date': '2019-08-04',
#   'game_datetime': '2019-08-04T23:05:00Z',
#   'game_id': 567517,
#   'game_num': 1,
#   'game_type': 'R',
#   'home_id': 147,
#   'home_name': 'New York Yankees',
#   'home_pitcher_note': 'Happ returns from the paternity list for his 22nd start of the season. He took the loss his last time out, though he logged a quality start by holding the D-backs to three runs and eight hits over six innings.',
#   'home_probable_pitcher': 'Happ, J.A.',
#   'home_score': 0,
#   'inning_state': 'Top',
#   'status': 'Pre-Game',
#   'summary': '2019-08-04 - Boston Red Sox @ New York Yankees (Pre-Game)'}]

# %%
pitching_past_N_games(5, get_player_id_from_name("J.A. Happ"))
# Out:
# OrderedDict([('avg_p5G', 0.303),
#              ('era_p5G', 5.04),
#              ('groundOutsToAirouts_p5G', 0.9),
#              ('hitsPer9Inn_p5G', 10.8),
#              ('homeRunsPer9_p5G', 1.44),
#              ('inningsPitched_p5G', 25.0),
#              ('pitchesPerInning_p5G', 17.56),
#              ('runsScoredPer9_p5G', 5.04),
#              ('stolenBasePercentage_p5G', 0.0),
#              ('strikePercentage_p5G', 0.63),
#              ('strikeoutWalkRatio_p5G', 2.56),
#              ('strikeoutsPer9Inn_p5G', 8.28),
#              ('walksPer9Inn_p5G', 3.24),
#              ('whip_p5G', 1.56),
#              ('winPercentage_p5G', 0.33)])

# %%
batting_past_N_games(5, get_player_id_from_name("Buster Posey"))
# Out:
# OrderedDict([('atBatsPerHomeRun_p5G', 0.0),
#              ('avg_p5G', 0.308),
#              ('hits_p5G', 4.0),
#              ('obp_p5G', 0.4),
#              ('ops_p5G', 0.785),
#              ('slg_p5G', 0.385)])

# %%
batting_past_N_games(7, get_player_id_from_name("Carlos Correa"))
# Out:
# OrderedDict([('atBatsPerHomeRun_p7G', 8.0),
#              ('avg_p7G', 0.417),
#              ('hits_p7G', 10.0),
#              ('obp_p7G', 0.548),
#              ('ops_p7G', 1.465),
#              ('slg_p7G', 0.917)])

# %%
batting_past_N_games(7, get_player_id_from_name("Trevor Story"))
# Out:
# OrderedDict([('atBatsPerHomeRun_p7G', 6.25),
#              ('avg_p7G', 0.32),
#              ('hits_p7G', 8.0),
#              ('obp_p7G', 0.414),
#              ('ops_p7G', 1.334),
#              ('slg_p7G', 0.92)])

# %%
yesterday = (datetime.datetime.today() - datetime.timedelta(days = 1)).strftime("%m/%d/%Y")
today = datetime.datetime.today().strftime("%m/%d/%Y")

# %%
pred_yest = pd.read_csv("data/predictions/predictions_{}.csv".format(yesterday.replace("/", "_")), index_col=0)
stats_yest = pd.read_csv("data/player_stats/player_stats_{}.csv".format(yesterday.replace("/", "_")))
# Out:
#                      Name  player_got_hit
# 33          Rafael Devers            True
# 62         Carlos Santana            True
# 158        Cody Bellinger            True
# 162         Justin Turner            True
# 166             Max Muncy           False
# 182      Christian Yelich            True
# 241      Charlie Blackmon            True
# 279       George Springer            True
# 354           Javier Baez            True
# 359  Nicholas Castellanos            True

# %%
past_results1 = stats_yest[stats_yest['Name'].isin(pred_yest['name'])].loc[:, ['Name', 'player_got_hit']]
past_results1.loc[10] = ['Overall Accuracy', str(sum(past_results1['player_got_hit']) * 10) + "%"]

# %%
past_results1.to_csv("data/past_results/past_results_{}.csv".format(yesterday.replace("/", "_")), index=False)
